# %%
import pandas as pd

# %%
df=pd.read_csv('Heart.csv')
df
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
df = df.drop(columns='Unnamed: 0')
df
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0     63    1       typical     145   233    1        2    150      0
# 1     67    1  asymptomatic     160   286    0        2    108      1
# 2     67    1  asymptomatic     120   229    0        2    129      1
# 3     37    1    nonanginal     130   250    0        0    187      0
# 4     41    0    nontypical     130   204    0        2    172      0
# ..   ...  ...           ...     ...   ...  ...      ...    ...    ...
# 298   45    1       typical     110   264    0        0    132      0
# 299   68    1  asymptomatic     144   193    1        0    141      0
# 300   57    1  asymptomatic     130   131    0        0    115      1
# 301   57    0    nontypical     130   236    0        2    174      0
# 302   38    1    nonanginal     138   175    0        0    173      0
#
#      Oldpeak  Slope   Ca        Thal  AHD
# 0        2.3      3  0.0       fixed   No
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPain', 'RestBP', 'Chol', 'Fbs', 'RestECG', 'MaxHR',
#        'ExAng', 'Oldpeak', 'Slope', 'Ca', 'Thal', 'AHD'],
#       dtype='object')

# %%
df['ChestPain']=df['ChestPain'].astype('category')
df['ChestPain']=df['ChestPain'].cat.codes
df
# Out:
#      Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0     63    1          3     145   233    1        2    150      0      2.3
# 1     67    1          0     160   286    0        2    108      1      1.5
# 2     67    1          0     120   229    0        2    129      1      2.6
# 3     37    1          1     130   250    0        0    187      0      3.5
# 4     41    0          2     130   204    0        2    172      0      1.4
# ..   ...  ...        ...     ...   ...  ...      ...    ...    ...      ...
# 298   45    1          3     110   264    0        0    132      0      1.2
# 299   68    1          0     144   193    1        0    141      0      3.4
# 300   57    1          0     130   131    0        0    115      1      1.2
# 301   57    0          2     130   236    0        2    174      0      0.0
# 302   38    1          1     138   175    0        0    173      0      0.0
#
#      Slope   Ca        Thal  AHD
# ...

# %%
df['Thal'] = df['Thal'].astype('category')
#astype veri tipini değiştirir
df['Thal'] = df['Thal'].cat.codes


df['AHD'] = df['AHD'].astype('category')
df['AHD'] = df['AHD'].cat.codes
df
# Out:
#      Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0     63    1          3     145   233    1        2    150      0      2.3
# 1     67    1          0     160   286    0        2    108      1      1.5
# 2     67    1          0     120   229    0        2    129      1      2.6
# 3     37    1          1     130   250    0        0    187      0      3.5
# 4     41    0          2     130   204    0        2    172      0      1.4
# ..   ...  ...        ...     ...   ...  ...      ...    ...    ...      ...
# 298   45    1          3     110   264    0        0    132      0      1.2
# 299   68    1          0     144   193    1        0    141      0      3.4
# 300   57    1          0     130   131    0        0    115      1      1.2
# 301   57    0          2     130   236    0        2    174      0      0.0
# 302   38    1          1     138   175    0        0    173      0      0.0
#
#      Slope   Ca  Thal  AHD
# 0        3  0.0     0    0
# ...

# %%
df.isnull().sum()
# null değerleri buluyo
# Out:
# Age          0
# Sex          0
# ChestPain    0
# RestBP       0
# Chol         0
# Fbs          0
# RestECG      0
# MaxHR        0
# ExAng        0
# Oldpeak      0
# Slope        0
# Ca           4
# Thal         0
# AHD          0
# dtype: int64

# %%
df = df.dropna()
#NaN değeri içeren satırlar silinir
df
# Out:
#      Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0     63    1          3     145   233    1        2    150      0      2.3
# 1     67    1          0     160   286    0        2    108      1      1.5
# 2     67    1          0     120   229    0        2    129      1      2.6
# 3     37    1          1     130   250    0        0    187      0      3.5
# 4     41    0          2     130   204    0        2    172      0      1.4
# ..   ...  ...        ...     ...   ...  ...      ...    ...    ...      ...
# 297   57    0          0     140   241    0        0    123      1      0.2
# 298   45    1          3     110   264    0        0    132      0      1.2
# 299   68    1          0     144   193    1        0    141      0      3.4
# 300   57    1          0     130   131    0        0    115      1      1.2
# 301   57    0          2     130   236    0        2    174      0      0.0
#
#      Slope   Ca  Thal  AHD
# 0        3  0.0     0    0
# ...

# %%
X = df.drop(columns = 'AHD')
#belirli sütunları işlemleriniz için çıkarmak veya seçmek için sıklıkla kullanılır
X
# Out:
#      Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0     63    1          3     145   233    1        2    150      0      2.3
# 1     67    1          0     160   286    0        2    108      1      1.5
# 2     67    1          0     120   229    0        2    129      1      2.6
# 3     37    1          1     130   250    0        0    187      0      3.5
# 4     41    0          2     130   204    0        2    172      0      1.4
# ..   ...  ...        ...     ...   ...  ...      ...    ...    ...      ...
# 297   57    0          0     140   241    0        0    123      1      0.2
# 298   45    1          3     110   264    0        0    132      0      1.2
# 299   68    1          0     144   193    1        0    141      0      3.4
# 300   57    1          0     130   131    0        0    115      1      1.2
# 301   57    0          2     130   236    0        2    174      0      0.0
#
#      Slope   Ca  Thal
# 0        3  0.0     0
# ...

# %%
y=df['AHD']
#AHD sütunundaki değerleri içermekte ve tek boyutlu bir veri yapısını temsil etmektedir

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=21)
#Bu işlem, genellikle makine öğrenimi modellerini eğitmek ve doğrulamak için kullanılan 
#veri setinin bir kısmını eğitim (training) için, 
#diğer kısmını ise test etmek (testing) için ayırmak için yapılır.

# %%
X_train
# Out:
#      Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 290   67    1          1     152   212    0        2    150      0      0.8
# 264   61    1          0     138   166    0        2    125      1      3.6
# 197   45    0          0     138   236    0        2    152      1      0.2
# 77    51    0          1     140   308    0        2    142      0      1.5
# 15    57    1          1     150   168    0        0    174      0      1.6
# ..   ...  ...        ...     ...   ...  ...      ...    ...    ...      ...
# 189   69    1          1     140   254    0        2    146      0      2.0
# 120   48    1          0     130   256    1        2    150      1      0.0
# 48    65    0          1     140   417    1        2    157      0      0.8
# 262   60    0          3     150   240    0        0    171      0      0.9
# 209   62    0          0     150   244    0        0    154      1      1.4
#
#      Slope   Ca  Thal
# 290      2  0.0     2
# ...

# %%
X_test
# Out:
#      Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 61    46    0          1     142   177    0        2    160      1      1.4
# 300   57    1          0     130   131    0        0    115      1      1.2
# 55    54    1          0     124   266    0        2    109      1      2.2
# 245   67    1          0     120   237    0        0     71      0      1.0
# 95    52    1          0     128   255    0        0    161      1      0.0
# ..   ...  ...        ...     ...   ...  ...      ...    ...    ...      ...
# 115   41    1          2     135   203    0        0    132      0      0.0
# 117   35    0          0     138   183    0        0    182      0      1.4
# 211   38    1          3     120   231    0        0    182      1      3.8
# 233   74    0          2     120   269    0        2    121      1      0.2
# 218   64    0          0     130   303    0        0    122      0      2.0
#
#      Slope   Ca  Thal
# 61       3  0.0     1
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %% [raw]
# scaler=StandardScaler()

# %% [raw]
# scaler = StandardScaler()
# X_train_scaled = scaler.fit_transform(X_train)

# %% [raw]
# X_test_scaled=scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 X_train_scaled
#
# NameError: name 'X_train_scaled' is not defined

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_reg=LogisticRegression(random_state = 0).fit(X_train_scaled,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 log_reg=LogisticRegression(random_state = 0).fit(X_train_scaled,y_train)
#
# NameError: name 'X_train_scaled' is not defined

# %%
log_reg.predict(X_train_scaled)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 log_reg.predict(X_train_scaled)
#
# NameError: name 'log_reg' is not defined

# %%
log_reg.score()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 log_reg.score()
#
# NameError: name 'log_reg' is not defined

# %%
log_reg.score(X_train_scaled,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 log_reg.score(X_train_scaled,y_train)
#
# NameError: name 'log_reg' is not defined

# %%
log_reg.score(X_train_scaled,y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 log_reg.score(X_train_scaled,y_test)
#
# NameError: name 'log_reg' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[116], line 3
#       1 log_reg1 = LogisticRegression(random_state=0,
#       2                              C=1
# ----> 3                             ).fit(X_train_scaled, y_train)
#
# NameError: name 'X_train_scaled' is not defined

# %%
log_reg1.score(X_train_scaled, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 log_reg1.score(X_train_scaled, y_train)
#
# NameError: name 'log_reg1' is not defined

# %%
log_reg1.score(X_test_scaled, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 log_reg1.score(X_test_scaled, y_test)
#
# NameError: name 'log_reg1' is not defined
